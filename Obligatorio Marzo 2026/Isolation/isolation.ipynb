# %%
from isolation_env import IsolationEnv
from input_agent import InputAgent
from random_agent import RandomAgent
from minimax import MiniMaxAgent
from expectimax import ExpectimaxAgent
from stratagem import Stratagem
from play import play_vs_other_agent

# %%
env = IsolationEnv()
input_agent = InputAgent()
env.action_space
# Out:
# Discrete(9)

# %% [markdown]
# Input Agents

# %%
#play_vs_other_agent(env, agent1=input_agent, agent2=input_agent)

# %% [markdown]
# Random Agents

# %%
MM = 0
EM = 0
for i in range(100):
    winnerMM = play_vs_other_agent(env, agent1=MiniMaxAgent(1), agent2=ExpectimaxAgent(2))    
    winnerEM = play_vs_other_agent(env, agent1=ExpectimaxAgent(1), agent2=MiniMaxAgent(2))
    if winnerMM == 1:
        MM += 1
    if winnerEM == 1:
        EM += 1
print("MiniMax:")
print(MM)
print("ExpectiMax:")
print(EM)
# Out:
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 2 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# ...

# %% [markdown]
# Random Agent vs Stratagem

# %%
play_vs_other_agent(env, agent1=RandomAgent(1), agent2=RandomAgent(2))
# Out:
# Player 2 WON
# '2'

# %% [markdown]
# Evaluacion de Funciones

# %%
RA = 0
MM = 0
EM = 0
for i in range(100):
    winnerRA = play_vs_other_agent(env, agent1=MiniMaxAgent(1), agent2=RandomAgent(2))
    winnerMM = play_vs_other_agent(env, agent1=MiniMaxAgent(1), agent2=MiniMaxAgent(2))
    winnerEM = play_vs_other_agent(env, agent1=MiniMaxAgent(1), agent2=ExpectimaxAgent(2))
    if winnerRA == 1:
        RA += 1
    if winnerMM == 1:
        MM += 1
    if winnerEM == 1:
        EM += 1
# Out:
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# Player 1 WON
# Player 2 WON
# Player 1 WON
# ...

# %%
print(RA)
print(MM)
print(EM)
# Out:
# 97
# 85
# 87
